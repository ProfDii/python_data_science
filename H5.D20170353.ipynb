# %% [markdown]
# # Description
#
# The goal of this code is to test my intuition on how to filter, arrange, and merge data.

# %%
# importing thee necessary libraries
import numpy as np
import scipy
import pandas as pd
import requests, zipfile, io
import urllib

# %% [markdown]
# ## Download and Load the World Development Indicators data set
#
# I will be working with the World Development Indicators data set. <br/>
# I will download this data set from the world bank databank.<br/>
# Hence, my very first step will be to download the data to my computer

# %%
#note this took several minutes. I think it depends on the speed of the internet connection
r = requests.get('http://databank.worldbank.org/data/download/WDI_csv.zip')
z = zipfile.ZipFile(io.BytesIO(r.content))
z.extractall()

# let us free the variales we used above
del z
del r

# %% [markdown]
# The above code downloaded a zip archive to my working folder, which by default was the the location of this notebook in my computer. <br/>
# Secondly, and since the document downloaded is a zip archive, it extracts the documents from the archive. <br/>
# The contents include multiple .csv files, however i will be working only with the document 'WDIData.csv'. <br/>
#
# In the cell below, we make use of Pandas to open the file "WDIData.csv" and save it to a variable called 'wdi'.<br/>

# %%
wdi = pd.read_csv("WDIData.csv", encoding="ISO-8859-1")

# %% [markdown]
# ## Download and Load the Penn World Table V9.0
#
# I will additionally be using data from the pwt v9.0 tables. <br/>

# %%
# downloading dataset using the library urllib
urllib.request.urlretrieve("https://www.rug.nl/ggdc/docs/pwt90.xlsx", "pwt90.xlsx")
# Out:
# ('pwt90.xlsx', <http.client.HTTPMessage at 0x11ccc9dd8>)

# %%
# opening and reading the filee 'pwt90.xlsx'
#using the read_excel pandas method for reading excel files
pwt = pd.read_excel("pwt90.xlsx", sheet_name="Data")

# %% [markdown]
# ## Data Wrangling
#
# Now that i have loaded my data into variable 'wdi', i am ready to start playing with it. <br/>
# I will Start by printing all column values in the cell bellow.

# %%
print(wdi.columns)
# Out:
# Index(['Country Name', 'Country Code', 'Indicator Name', 'Indicator Code',
#        '1960', '1961', '1962', '1963', '1964', '1965', '1966', '1967', '1968',
#        '1969', '1970', '1971', '1972', '1973', '1974', '1975', '1976', '1977',
#        '1978', '1979', '1980', '1981', '1982', '1983', '1984', '1985', '1986',
#        '1987', '1988', '1989', '1990', '1991', '1992', '1993', '1994', '1995',
#        '1996', '1997', '1998', '1999', '2000', '2001', '2002', '2003', '2004',
#        '2005', '2006', '2007', '2008', '2009', '2010', '2011', '2012', '2013',
#        '2014', '2015', '2016', '2017', 'Unnamed: 62'],
#       dtype='object')

# %% [markdown]
# Next, i will list the values in the column 'Country Name'.<br/>
# I got a list with repeated values, i will be deleting all duplicates to ease my analysis. <br/>

# %%
wdi['Country Name']
wdi.drop_duplicates(['Country Name'])
# Out:
#                                              Country Name Country Code  \
# 0                                              Arab World          ARB
# 1600                               Caribbean small states          CSS
# 3200                       Central Europe and the Baltics          CEB
# 4800                           Early-demographic dividend          EAR
# 6400                                  East Asia & Pacific          EAS
# 8000          East Asia & Pacific (excluding high income)          EAP
# 9600           East Asia & Pacific (IDA & IBRD countries)          TEA
# 11200                                           Euro area          EMU
# 12800                               Europe & Central Asia          ECS
# 14400       Europe & Central Asia (excluding high income)          ECA
# 16000        Europe & Central Asia (IDA & IBRD countries)          TEC
# 17600                                      European Union          EUU
# 19200            Fragile and conflict affected situations          FCS
# 20800              Heavily indebted poor countries (HIPC)          HPC
# 22400                                         High income          HIC
# 24000                                           IBRD only          IBD
# 25600                                    IDA & IBRD total          IBT
# 27200                                           IDA blend          IDB
# 28800                                            IDA only          IDX
# 30400                                           IDA total          IDA
# 32000                           Late-demographic dividend          LTE
# 33600                           Latin America & Caribbean          LCN
# 35200   Latin America & Caribbean (excluding high income)          LAC
# 36800   Latin America & the Caribbean (IDA & IBRD coun...          TLA
# 38400        Least developed countries: UN classification          LDC
# 40000                                 Low & middle income          LMY
# 41600                                          Low income          LIC
# 43200                                 Lower middle income          LMC
# 44800                          Middle East & North Africa          MEA
# 46400   Middle East & North Africa (excluding high inc...          MNA
# ...                                                   ...          ...
# 374400                                             Sweden          SWE
# 376000                                        Switzerland          CHE
# 377600                               Syrian Arab Republic          SYR
# 379200                                         Tajikistan          TJK
# 380800                                           Tanzania          TZA
# 382400                                           Thailand          THA
# 384000                                        Timor-Leste          TLS
# 385600                                               Togo          TGO
# 387200                                              Tonga          TON
# 388800                                Trinidad and Tobago          TTO
# 390400                                            Tunisia          TUN
# 392000                                             Turkey          TUR
# 393600                                       Turkmenistan          TKM
# 395200                           Turks and Caicos Islands          TCA
# 396800                                             Tuvalu          TUV
# 398400                                             Uganda          UGA
# 400000                                            Ukraine          UKR
# 401600                               United Arab Emirates          ARE
# 403200                                     United Kingdom          GBR
# 404800                                      United States          USA
# 406400                                            Uruguay          URY
# 408000                                         Uzbekistan          UZB
# 409600                                            Vanuatu          VUT
# 411200                                      Venezuela, RB          VEN
# 412800                                            Vietnam          VNM
# 414400                              Virgin Islands (U.S.)          VIR
# 416000                                 West Bank and Gaza          PSE
# 417600                                        Yemen, Rep.          YEM
# 419200                                             Zambia          ZMB
# 420800                                           Zimbabwe          ZWE
#
#                                            Indicator Name Indicator Code  \
# 0       2005 PPP conversion factor, GDP (LCU per inter...  PA.NUS.PPP.05
# 1600    2005 PPP conversion factor, GDP (LCU per inter...  PA.NUS.PPP.05
# 3200    2005 PPP conversion factor, GDP (LCU per inter...  PA.NUS.PPP.05
# 4800    2005 PPP conversion factor, GDP (LCU per inter...  PA.NUS.PPP.05
# 6400    2005 PPP conversion factor, GDP (LCU per inter...  PA.NUS.PPP.05
# 8000    2005 PPP conversion factor, GDP (LCU per inter...  PA.NUS.PPP.05
# 9600    2005 PPP conversion factor, GDP (LCU per inter...  PA.NUS.PPP.05
# 11200   2005 PPP conversion factor, GDP (LCU per inter...  PA.NUS.PPP.05
# 12800   2005 PPP conversion factor, GDP (LCU per inter...  PA.NUS.PPP.05
# 14400   2005 PPP conversion factor, GDP (LCU per inter...  PA.NUS.PPP.05
# 16000   2005 PPP conversion factor, GDP (LCU per inter...  PA.NUS.PPP.05
# 17600   2005 PPP conversion factor, GDP (LCU per inter...  PA.NUS.PPP.05
# 19200   2005 PPP conversion factor, GDP (LCU per inter...  PA.NUS.PPP.05
# 20800   2005 PPP conversion factor, GDP (LCU per inter...  PA.NUS.PPP.05
# 22400   2005 PPP conversion factor, GDP (LCU per inter...  PA.NUS.PPP.05
# 24000   2005 PPP conversion factor, GDP (LCU per inter...  PA.NUS.PPP.05
# 25600   2005 PPP conversion factor, GDP (LCU per inter...  PA.NUS.PPP.05
# 27200   2005 PPP conversion factor, GDP (LCU per inter...  PA.NUS.PPP.05
# 28800   2005 PPP conversion factor, GDP (LCU per inter...  PA.NUS.PPP.05
# 30400   2005 PPP conversion factor, GDP (LCU per inter...  PA.NUS.PPP.05
# 32000   2005 PPP conversion factor, GDP (LCU per inter...  PA.NUS.PPP.05
# 33600   2005 PPP conversion factor, GDP (LCU per inter...  PA.NUS.PPP.05
# 35200   2005 PPP conversion factor, GDP (LCU per inter...  PA.NUS.PPP.05
# 36800   2005 PPP conversion factor, GDP (LCU per inter...  PA.NUS.PPP.05
# 38400   2005 PPP conversion factor, GDP (LCU per inter...  PA.NUS.PPP.05
# 40000   2005 PPP conversion factor, GDP (LCU per inter...  PA.NUS.PPP.05
# 41600   2005 PPP conversion factor, GDP (LCU per inter...  PA.NUS.PPP.05
# 43200   2005 PPP conversion factor, GDP (LCU per inter...  PA.NUS.PPP.05
# 44800   2005 PPP conversion factor, GDP (LCU per inter...  PA.NUS.PPP.05
# 46400   2005 PPP conversion factor, GDP (LCU per inter...  PA.NUS.PPP.05
# ...                                                   ...            ...
# 374400  2005 PPP conversion factor, GDP (LCU per inter...  PA.NUS.PPP.05
# 376000  2005 PPP conversion factor, GDP (LCU per inter...  PA.NUS.PPP.05
# 377600  2005 PPP conversion factor, GDP (LCU per inter...  PA.NUS.PPP.05
# 379200  2005 PPP conversion factor, GDP (LCU per inter...  PA.NUS.PPP.05
# 380800  2005 PPP conversion factor, GDP (LCU per inter...  PA.NUS.PPP.05
# 382400  2005 PPP conversion factor, GDP (LCU per inter...  PA.NUS.PPP.05
# 384000  2005 PPP conversion factor, GDP (LCU per inter...  PA.NUS.PPP.05
# 385600  2005 PPP conversion factor, GDP (LCU per inter...  PA.NUS.PPP.05
# 387200  2005 PPP conversion factor, GDP (LCU per inter...  PA.NUS.PPP.05
# 388800  2005 PPP conversion factor, GDP (LCU per inter...  PA.NUS.PPP.05
# 390400  2005 PPP conversion factor, GDP (LCU per inter...  PA.NUS.PPP.05
# 392000  2005 PPP conversion factor, GDP (LCU per inter...  PA.NUS.PPP.05
# 393600  2005 PPP conversion factor, GDP (LCU per inter...  PA.NUS.PPP.05
# 395200  2005 PPP conversion factor, GDP (LCU per inter...  PA.NUS.PPP.05
# 396800  2005 PPP conversion factor, GDP (LCU per inter...  PA.NUS.PPP.05
# 398400  2005 PPP conversion factor, GDP (LCU per inter...  PA.NUS.PPP.05
# 400000  2005 PPP conversion factor, GDP (LCU per inter...  PA.NUS.PPP.05
# 401600  2005 PPP conversion factor, GDP (LCU per inter...  PA.NUS.PPP.05
# 403200  2005 PPP conversion factor, GDP (LCU per inter...  PA.NUS.PPP.05
# 404800  2005 PPP conversion factor, GDP (LCU per inter...  PA.NUS.PPP.05
# 406400  2005 PPP conversion factor, GDP (LCU per inter...  PA.NUS.PPP.05
# 408000  2005 PPP conversion factor, GDP (LCU per inter...  PA.NUS.PPP.05
# 409600  2005 PPP conversion factor, GDP (LCU per inter...  PA.NUS.PPP.05
# 411200  2005 PPP conversion factor, GDP (LCU per inter...  PA.NUS.PPP.05
# 412800  2005 PPP conversion factor, GDP (LCU per inter...  PA.NUS.PPP.05
# 414400  2005 PPP conversion factor, GDP (LCU per inter...  PA.NUS.PPP.05
# 416000  2005 PPP conversion factor, GDP (LCU per inter...  PA.NUS.PPP.05
# 417600  2005 PPP conversion factor, GDP (LCU per inter...  PA.NUS.PPP.05
# 419200  2005 PPP conversion factor, GDP (LCU per inter...  PA.NUS.PPP.05
# 420800  2005 PPP conversion factor, GDP (LCU per inter...  PA.NUS.PPP.05
#
#         1960  1961  1962  1963  1964  1965     ...       2009  2010  2011  \
# 0        NaN   NaN   NaN   NaN   NaN   NaN     ...        NaN   NaN   NaN
# 1600     NaN   NaN   NaN   NaN   NaN   NaN     ...        NaN   NaN   NaN
# 3200     NaN   NaN   NaN   NaN   NaN   NaN     ...        NaN   NaN   NaN
# 4800     NaN   NaN   NaN   NaN   NaN   NaN     ...        NaN   NaN   NaN
# 6400     NaN   NaN   NaN   NaN   NaN   NaN     ...        NaN   NaN   NaN
# 8000     NaN   NaN   NaN   NaN   NaN   NaN     ...        NaN   NaN   NaN
# 9600     NaN   NaN   NaN   NaN   NaN   NaN     ...        NaN   NaN   NaN
# 11200    NaN   NaN   NaN   NaN   NaN   NaN     ...        NaN   NaN   NaN
# 12800    NaN   NaN   NaN   NaN   NaN   NaN     ...        NaN   NaN   NaN
# 14400    NaN   NaN   NaN   NaN   NaN   NaN     ...        NaN   NaN   NaN
# 16000    NaN   NaN   NaN   NaN   NaN   NaN     ...        NaN   NaN   NaN
# 17600    NaN   NaN   NaN   NaN   NaN   NaN     ...        NaN   NaN   NaN
# 19200    NaN   NaN   NaN   NaN   NaN   NaN     ...        NaN   NaN   NaN
# 20800    NaN   NaN   NaN   NaN   NaN   NaN     ...        NaN   NaN   NaN
# 22400    NaN   NaN   NaN   NaN   NaN   NaN     ...        NaN   NaN   NaN
# 24000    NaN   NaN   NaN   NaN   NaN   NaN     ...        NaN   NaN   NaN
# 25600    NaN   NaN   NaN   NaN   NaN   NaN     ...        NaN   NaN   NaN
# 27200    NaN   NaN   NaN   NaN   NaN   NaN     ...        NaN   NaN   NaN
# 28800    NaN   NaN   NaN   NaN   NaN   NaN     ...        NaN   NaN   NaN
# 30400    NaN   NaN   NaN   NaN   NaN   NaN     ...        NaN   NaN   NaN
# 32000    NaN   NaN   NaN   NaN   NaN   NaN     ...        NaN   NaN   NaN
# 33600    NaN   NaN   NaN   NaN   NaN   NaN     ...        NaN   NaN   NaN
# 35200    NaN   NaN   NaN   NaN   NaN   NaN     ...        NaN   NaN   NaN
# 36800    NaN   NaN   NaN   NaN   NaN   NaN     ...        NaN   NaN   NaN
# 38400    NaN   NaN   NaN   NaN   NaN   NaN     ...        NaN   NaN   NaN
# 40000    NaN   NaN   NaN   NaN   NaN   NaN     ...        NaN   NaN   NaN
# 41600    NaN   NaN   NaN   NaN   NaN   NaN     ...        NaN   NaN   NaN
# 43200    NaN   NaN   NaN   NaN   NaN   NaN     ...        NaN   NaN   NaN
# 44800    NaN   NaN   NaN   NaN   NaN   NaN     ...        NaN   NaN   NaN
# 46400    NaN   NaN   NaN   NaN   NaN   NaN     ...        NaN   NaN   NaN
# ...      ...   ...   ...   ...   ...   ...     ...        ...   ...   ...
# 374400   NaN   NaN   NaN   NaN   NaN   NaN     ...        NaN   NaN   NaN
# 376000   NaN   NaN   NaN   NaN   NaN   NaN     ...        NaN   NaN   NaN
# 377600   NaN   NaN   NaN   NaN   NaN   NaN     ...        NaN   NaN   NaN
# 379200   NaN   NaN   NaN   NaN   NaN   NaN     ...        NaN   NaN   NaN
# 380800   NaN   NaN   NaN   NaN   NaN   NaN     ...        NaN   NaN   NaN
# 382400   NaN   NaN   NaN   NaN   NaN   NaN     ...        NaN   NaN   NaN
# 384000   NaN   NaN   NaN   NaN   NaN   NaN     ...        NaN   NaN   NaN
# 385600   NaN   NaN   NaN   NaN   NaN   NaN     ...        NaN   NaN   NaN
# 387200   NaN   NaN   NaN   NaN   NaN   NaN     ...        NaN   NaN   NaN
# 388800   NaN   NaN   NaN   NaN   NaN   NaN     ...        NaN   NaN   NaN
# 390400   NaN   NaN   NaN   NaN   NaN   NaN     ...        NaN   NaN   NaN
# 392000   NaN   NaN   NaN   NaN   NaN   NaN     ...        NaN   NaN   NaN
# 393600   NaN   NaN   NaN   NaN   NaN   NaN     ...        NaN   NaN   NaN
# 395200   NaN   NaN   NaN   NaN   NaN   NaN     ...        NaN   NaN   NaN
# 396800   NaN   NaN   NaN   NaN   NaN   NaN     ...        NaN   NaN   NaN
# 398400   NaN   NaN   NaN   NaN   NaN   NaN     ...        NaN   NaN   NaN
# 400000   NaN   NaN   NaN   NaN   NaN   NaN     ...        NaN   NaN   NaN
# 401600   NaN   NaN   NaN   NaN   NaN   NaN     ...        NaN   NaN   NaN
# 403200   NaN   NaN   NaN   NaN   NaN   NaN     ...        NaN   NaN   NaN
# 404800   NaN   NaN   NaN   NaN   NaN   NaN     ...        NaN   NaN   NaN
# 406400   NaN   NaN   NaN   NaN   NaN   NaN     ...        NaN   NaN   NaN
# 408000   NaN   NaN   NaN   NaN   NaN   NaN     ...        NaN   NaN   NaN
# 409600   NaN   NaN   NaN   NaN   NaN   NaN     ...        NaN   NaN   NaN
# 411200   NaN   NaN   NaN   NaN   NaN   NaN     ...        NaN   NaN   NaN
# 412800   NaN   NaN   NaN   NaN   NaN   NaN     ...        NaN   NaN   NaN
# 414400   NaN   NaN   NaN   NaN   NaN   NaN     ...        NaN   NaN   NaN
# 416000   NaN   NaN   NaN   NaN   NaN   NaN     ...        NaN   NaN   NaN
# 417600   NaN   NaN   NaN   NaN   NaN   NaN     ...        NaN   NaN   NaN
# 419200   NaN   NaN   NaN   NaN   NaN   NaN     ...        NaN   NaN   NaN
# 420800   NaN   NaN   NaN   NaN   NaN   NaN     ...        NaN   NaN   NaN
#
#         2012  2013  2014  2015  2016  2017  Unnamed: 62
# 0        NaN   NaN   NaN   NaN   NaN   NaN          NaN
# 1600     NaN   NaN   NaN   NaN   NaN   NaN          NaN
# 3200     NaN   NaN   NaN   NaN   NaN   NaN          NaN
# 4800     NaN   NaN   NaN   NaN   NaN   NaN          NaN
# 6400     NaN   NaN   NaN   NaN   NaN   NaN          NaN
# 8000     NaN   NaN   NaN   NaN   NaN   NaN          NaN
# 9600     NaN   NaN   NaN   NaN   NaN   NaN          NaN
# 11200    NaN   NaN   NaN   NaN   NaN   NaN          NaN
# 12800    NaN   NaN   NaN   NaN   NaN   NaN          NaN
# 14400    NaN   NaN   NaN   NaN   NaN   NaN          NaN
# 16000    NaN   NaN   NaN   NaN   NaN   NaN          NaN
# 17600    NaN   NaN   NaN   NaN   NaN   NaN          NaN
# 19200    NaN   NaN   NaN   NaN   NaN   NaN          NaN
# 20800    NaN   NaN   NaN   NaN   NaN   NaN          NaN
# 22400    NaN   NaN   NaN   NaN   NaN   NaN          NaN
# 24000    NaN   NaN   NaN   NaN   NaN   NaN          NaN
# 25600    NaN   NaN   NaN   NaN   NaN   NaN          NaN
# 27200    NaN   NaN   NaN   NaN   NaN   NaN          NaN
# 28800    NaN   NaN   NaN   NaN   NaN   NaN          NaN
# 30400    NaN   NaN   NaN   NaN   NaN   NaN          NaN
# 32000    NaN   NaN   NaN   NaN   NaN   NaN          NaN
# 33600    NaN   NaN   NaN   NaN   NaN   NaN          NaN
# 35200    NaN   NaN   NaN   NaN   NaN   NaN          NaN
# 36800    NaN   NaN   NaN   NaN   NaN   NaN          NaN
# 38400    NaN   NaN   NaN   NaN   NaN   NaN          NaN
# 40000    NaN   NaN   NaN   NaN   NaN   NaN          NaN
# 41600    NaN   NaN   NaN   NaN   NaN   NaN          NaN
# 43200    NaN   NaN   NaN   NaN   NaN   NaN          NaN
# 44800    NaN   NaN   NaN   NaN   NaN   NaN          NaN
# 46400    NaN   NaN   NaN   NaN   NaN   NaN          NaN
# ...      ...   ...   ...   ...   ...   ...          ...
# 374400   NaN   NaN   NaN   NaN   NaN   NaN          NaN
# 376000   NaN   NaN   NaN   NaN   NaN   NaN          NaN
# 377600   NaN   NaN   NaN   NaN   NaN   NaN          NaN
# 379200   NaN   NaN   NaN   NaN   NaN   NaN          NaN
# 380800   NaN   NaN   NaN   NaN   NaN   NaN          NaN
# 382400   NaN   NaN   NaN   NaN   NaN   NaN          NaN
# 384000   NaN   NaN   NaN   NaN   NaN   NaN          NaN
# 385600   NaN   NaN   NaN   NaN   NaN   NaN          NaN
# 387200   NaN   NaN   NaN   NaN   NaN   NaN          NaN
# 388800   NaN   NaN   NaN   NaN   NaN   NaN          NaN
# 390400   NaN   NaN   NaN   NaN   NaN   NaN          NaN
# 392000   NaN   NaN   NaN   NaN   NaN   NaN          NaN
# 393600   NaN   NaN   NaN   NaN   NaN   NaN          NaN
# 395200   NaN   NaN   NaN   NaN   NaN   NaN          NaN
# 396800   NaN   NaN   NaN   NaN   NaN   NaN          NaN
# 398400   NaN   NaN   NaN   NaN   NaN   NaN          NaN
# 400000   NaN   NaN   NaN   NaN   NaN   NaN          NaN
# 401600   NaN   NaN   NaN   NaN   NaN   NaN          NaN
# 403200   NaN   NaN   NaN   NaN   NaN   NaN          NaN
# 404800   NaN   NaN   NaN   NaN   NaN   NaN          NaN
# 406400   NaN   NaN   NaN   NaN   NaN   NaN          NaN
# 408000   NaN   NaN   NaN   NaN   NaN   NaN          NaN
# 409600   NaN   NaN   NaN   NaN   NaN   NaN          NaN
# 411200   NaN   NaN   NaN   NaN   NaN   NaN          NaN
# 412800   NaN   NaN   NaN   NaN   NaN   NaN          NaN
# 414400   NaN   NaN   NaN   NaN   NaN   NaN          NaN
# 416000   NaN   NaN   NaN   NaN   NaN   NaN          NaN
# 417600   NaN   NaN   NaN   NaN   NaN   NaN          NaN
# 419200   NaN   NaN   NaN   NaN   NaN   NaN          NaN
# 420800   NaN   NaN   NaN   NaN   NaN   NaN          NaN
#
# [264 rows x 63 columns]

# %% [markdown]
# I noticed that while the bottom rows represent Countries, the top rows represent aggregates of countries (e.g., world regions). <br/> However i am only interested in working with country-level data, and as such i need to filter out all unecessary rows.

# %%
cnames = wdi['Country Name']
cnames = cnames.drop_duplicates()

# %%
cnames[0:51]
# Out:
# 0                                               Arab World
# 1600                                Caribbean small states
# 3200                        Central Europe and the Baltics
# 4800                            Early-demographic dividend
# 6400                                   East Asia & Pacific
# 8000           East Asia & Pacific (excluding high income)
# 9600            East Asia & Pacific (IDA & IBRD countries)
# 11200                                            Euro area
# 12800                                Europe & Central Asia
# 14400        Europe & Central Asia (excluding high income)
# 16000         Europe & Central Asia (IDA & IBRD countries)
# 17600                                       European Union
# 19200             Fragile and conflict affected situations
# 20800               Heavily indebted poor countries (HIPC)
# 22400                                          High income
# 24000                                            IBRD only
# 25600                                     IDA & IBRD total
# 27200                                            IDA blend
# 28800                                             IDA only
# 30400                                            IDA total
# 32000                            Late-demographic dividend
# 33600                            Latin America & Caribbean
# 35200    Latin America & Caribbean (excluding high income)
# 36800    Latin America & the Caribbean (IDA & IBRD coun...
# 38400         Least developed countries: UN classification
# 40000                                  Low & middle income
# 41600                                           Low income
# 43200                                  Lower middle income
# 44800                           Middle East & North Africa
# 46400    Middle East & North Africa (excluding high inc...
# 48000    Middle East & North Africa (IDA & IBRD countries)
# 49600                                        Middle income
# 51200                                        North America
# 52800                                       Not classified
# 54400                                         OECD members
# 56000                                   Other small states
# 57600                          Pacific island small states
# 59200                            Post-demographic dividend
# 60800                             Pre-demographic dividend
# 62400                                         Small states
# 64000                                           South Asia
# 65600                              South Asia (IDA & IBRD)
# 67200                                   Sub-Saharan Africa
# 68800           Sub-Saharan Africa (excluding high income)
# 70400            Sub-Saharan Africa (IDA & IBRD countries)
# 72000                                  Upper middle income
# 73600                                                World
# 75200                                          Afghanistan
# 76800                                              Albania
# 78400                                              Algeria
# 80000                                       American Samoa
# Name: Country Name, dtype: object

# %% [markdown]
# I verified that the first 48 values in cnames 'Country Name' do not correspond to countries, but aggregates.<br/>
# In the next cell, i will filter out, from 'wdi', rows in which 'Country Name' represents an aggregate of countries.<br/>

# %%
wdi = wdi.loc[~wdi['Country Name'].isin(cnames[0:47])]

# %%
# resetting thee indexes of wdi, performing this operation in places
wdi.reset_index(inplace = True)

# %%
wdi
# Out:
#          index Country Name Country Code  \
# 0        75200  Afghanistan          AFG
# 1        75201  Afghanistan          AFG
# 2        75202  Afghanistan          AFG
# 3        75203  Afghanistan          AFG
# 4        75204  Afghanistan          AFG
# 5        75205  Afghanistan          AFG
# 6        75206  Afghanistan          AFG
# 7        75207  Afghanistan          AFG
# 8        75208  Afghanistan          AFG
# 9        75209  Afghanistan          AFG
# 10       75210  Afghanistan          AFG
# 11       75211  Afghanistan          AFG
# 12       75212  Afghanistan          AFG
# 13       75213  Afghanistan          AFG
# 14       75214  Afghanistan          AFG
# 15       75215  Afghanistan          AFG
# 16       75216  Afghanistan          AFG
# 17       75217  Afghanistan          AFG
# 18       75218  Afghanistan          AFG
# 19       75219  Afghanistan          AFG
# 20       75220  Afghanistan          AFG
# 21       75221  Afghanistan          AFG
# 22       75222  Afghanistan          AFG
# 23       75223  Afghanistan          AFG
# 24       75224  Afghanistan          AFG
# 25       75225  Afghanistan          AFG
# 26       75226  Afghanistan          AFG
# 27       75227  Afghanistan          AFG
# 28       75228  Afghanistan          AFG
# 29       75229  Afghanistan          AFG
# ...        ...          ...          ...
# 347170  422370     Zimbabwe          ZWE
# 347171  422371     Zimbabwe          ZWE
# 347172  422372     Zimbabwe          ZWE
# 347173  422373     Zimbabwe          ZWE
# 347174  422374     Zimbabwe          ZWE
# 347175  422375     Zimbabwe          ZWE
# 347176  422376     Zimbabwe          ZWE
# 347177  422377     Zimbabwe          ZWE
# 347178  422378     Zimbabwe          ZWE
# 347179  422379     Zimbabwe          ZWE
# 347180  422380     Zimbabwe          ZWE
# 347181  422381     Zimbabwe          ZWE
# 347182  422382     Zimbabwe          ZWE
# 347183  422383     Zimbabwe          ZWE
# 347184  422384     Zimbabwe          ZWE
# 347185  422385     Zimbabwe          ZWE
# 347186  422386     Zimbabwe          ZWE
# 347187  422387     Zimbabwe          ZWE
# 347188  422388     Zimbabwe          ZWE
# 347189  422389     Zimbabwe          ZWE
# 347190  422390     Zimbabwe          ZWE
# 347191  422391     Zimbabwe          ZWE
# 347192  422392     Zimbabwe          ZWE
# 347193  422393     Zimbabwe          ZWE
# 347194  422394     Zimbabwe          ZWE
# 347195  422395     Zimbabwe          ZWE
# 347196  422396     Zimbabwe          ZWE
# 347197  422397     Zimbabwe          ZWE
# 347198  422398     Zimbabwe          ZWE
# 347199  422399     Zimbabwe          ZWE
#
#                                            Indicator Name  \
# 0       2005 PPP conversion factor, GDP (LCU per inter...
# 1       2005 PPP conversion factor, private consumptio...
# 2       Access to clean fuels and technologies for coo...
# 3                 Access to electricity (% of population)
# 4       Access to electricity, rural (% of rural popul...
# 5       Access to electricity, urban (% of urban popul...
# 6       Account ownership at a financial institution o...
# 7       Account ownership at a financial institution o...
# 8       Account ownership at a financial institution o...
# 9       Account ownership at a financial institution o...
# 10      Account ownership at a financial institution o...
# 11      Account ownership at a financial institution o...
# 12      Account ownership at a financial institution o...
# 13      Account ownership at a financial institution o...
# 14      Account ownership at a financial institution o...
# 15      Adequacy of social insurance programs (% of to...
# 16      Adequacy of social protection and labor progra...
# 17      Adequacy of social safety net programs (% of t...
# 18      Adequacy of unemployment benefits and ALMP (% ...
# 19      Adjusted net enrollment rate, primary (% of pr...
# 20      Adjusted net enrollment rate, primary, female ...
# 21      Adjusted net enrollment rate, primary, male (%...
# 22         Adjusted net national income (annual % growth)
# 23       Adjusted net national income (constant 2010 US$)
# 24             Adjusted net national income (current US$)
# 25      Adjusted net national income per capita (annua...
# 26      Adjusted net national income per capita (const...
# 27      Adjusted net national income per capita (curre...
# 28      Adjusted net savings, excluding particulate em...
# 29      Adjusted net savings, excluding particulate em...
# ...                                                   ...
# 347170                                   Urban population
# 347171                      Urban population (% of total)
# 347172                 Urban population growth (annual %)
# 347173  Urban population living in areas where elevati...
# 347174    Urban poverty gap at national poverty lines (%)
# 347175  Urban poverty headcount ratio at national pove...
# 347176               Use of IMF credit (DOD, current US$)
# 347177  Use of insecticide-treated bed nets (% of unde...
# 347178  Value lost due to electrical outages (% of sal...
# 347179  Vitamin A supplementation coverage rate (% of ...
# 347180  Vulnerable employment, female (% of female emp...
# 347181  Vulnerable employment, male (% of male employm...
# 347182  Vulnerable employment, total (% of total emplo...
# 347183  Wage and salaried workers, female (% of female...
# 347184  Wage and salaried workers, male (% of male emp...
# 347185  Wage and salaried workers, total (% of total e...
# 347186           Wanted fertility rate (births per woman)
# 347187  Water productivity, total (constant 2010 US$ G...
# 347188                 Wholesale price index (2010 = 100)
# 347189  Women making their own informed decisions rega...
# 347190  Women participating in the three decisions (ow...
# 347191  Women who believe a husband is justified in be...
# 347192  Women who believe a husband is justified in be...
# 347193  Women who believe a husband is justified in be...
# 347194  Women who believe a husband is justified in be...
# 347195  Women who believe a husband is justified in be...
# 347196  Women who believe a husband is justified in be...
# 347197  Women who were first married by age 15 (% of w...
# 347198  Women who were first married by age 18 (% of w...
# 347199  Women's share of population ages 15+ living wi...
#
#                   Indicator Code           1960           1961           1962  \
# 0                  PA.NUS.PPP.05            NaN            NaN            NaN
# 1              PA.NUS.PRVT.PP.05            NaN            NaN            NaN
# 2                 EG.CFT.ACCS.ZS            NaN            NaN            NaN
# 3                 EG.ELC.ACCS.ZS            NaN            NaN            NaN
# 4              EG.ELC.ACCS.RU.ZS            NaN            NaN            NaN
# 5              EG.ELC.ACCS.UR.ZS            NaN            NaN            NaN
# 6                 FX.OWN.TOTL.ZS            NaN            NaN            NaN
# 7              FX.OWN.TOTL.FE.ZS            NaN            NaN            NaN
# 8              FX.OWN.TOTL.MA.ZS            NaN            NaN            NaN
# 9              FX.OWN.TOTL.OL.ZS            NaN            NaN            NaN
# 10             FX.OWN.TOTL.40.ZS            NaN            NaN            NaN
# 11             FX.OWN.TOTL.PL.ZS            NaN            NaN            NaN
# 12             FX.OWN.TOTL.60.ZS            NaN            NaN            NaN
# 13             FX.OWN.TOTL.SO.ZS            NaN            NaN            NaN
# 14             FX.OWN.TOTL.YG.ZS            NaN            NaN            NaN
# 15      per_si_allsi.adq_pop_tot            NaN            NaN            NaN
# 16         per_allsp.adq_pop_tot            NaN            NaN            NaN
# 17      per_sa_allsa.adq_pop_tot            NaN            NaN            NaN
# 18      per_lm_alllm.adq_pop_tot            NaN            NaN            NaN
# 19                   SE.PRM.TENR            NaN            NaN            NaN
# 20                SE.PRM.TENR.FE            NaN            NaN            NaN
# 21                SE.PRM.TENR.MA            NaN            NaN            NaN
# 22             NY.ADJ.NNTY.KD.ZG            NaN            NaN            NaN
# 23                NY.ADJ.NNTY.KD            NaN            NaN            NaN
# 24                NY.ADJ.NNTY.CD            NaN            NaN            NaN
# 25          NY.ADJ.NNTY.PC.KD.ZG            NaN            NaN            NaN
# 26             NY.ADJ.NNTY.PC.KD            NaN            NaN            NaN
# 27             NY.ADJ.NNTY.PC.CD            NaN            NaN            NaN
# 28             NY.ADJ.SVNX.GN.ZS            NaN            NaN            NaN
# 29                NY.ADJ.SVNX.CD            NaN            NaN            NaN
# ...                          ...            ...            ...            ...
# 347170               SP.URB.TOTL  472468.000000  496270.000000  523204.000000
# 347171         SP.URB.TOTL.IN.ZS      12.608000      12.821000      13.082000
# 347172               SP.URB.GROW       4.879355       4.915011       5.285131
# 347173         EN.POP.EL5M.UR.ZS            NaN            NaN            NaN
# 347174               SI.POV.URGP            NaN            NaN            NaN
# 347175               SI.POV.URHC            NaN            NaN            NaN
# 347176            DT.DOD.DIMF.CD            NaN            NaN            NaN
# 347177            SH.MLR.NETS.ZS            NaN            NaN            NaN
# 347178            IC.FRM.OUTG.ZS            NaN            NaN            NaN
# 347179            SN.ITK.VITA.ZS            NaN            NaN            NaN
# 347180         SL.EMP.VULN.FE.ZS            NaN            NaN            NaN
# 347181         SL.EMP.VULN.MA.ZS            NaN            NaN            NaN
# 347182            SL.EMP.VULN.ZS            NaN            NaN            NaN
# 347183         SL.EMP.WORK.FE.ZS            NaN            NaN            NaN
# 347184         SL.EMP.WORK.MA.ZS            NaN            NaN            NaN
# 347185            SL.EMP.WORK.ZS            NaN            NaN            NaN
# 347186               SP.DYN.WFRT            NaN            NaN            NaN
# 347187         ER.GDP.FWTL.M3.KD            NaN            NaN            NaN
# 347188               FP.WPI.TOTL            NaN            NaN            NaN
# 347189         SG.DMK.SRCR.FN.ZS            NaN            NaN            NaN
# 347190         SG.DMK.ALLD.FN.ZS            NaN            NaN            NaN
# 347191            SG.VAW.REAS.ZS            NaN            NaN            NaN
# 347192            SG.VAW.ARGU.ZS            NaN            NaN            NaN
# 347193            SG.VAW.BURN.ZS            NaN            NaN            NaN
# 347194            SG.VAW.GOES.ZS            NaN            NaN            NaN
# 347195            SG.VAW.NEGL.ZS            NaN            NaN            NaN
# 347196            SG.VAW.REFU.ZS            NaN            NaN            NaN
# 347197         SP.M15.2024.FE.ZS            NaN            NaN            NaN
# 347198         SP.M18.2024.FE.ZS            NaN            NaN            NaN
# 347199         SH.DYN.AIDS.FE.ZS            NaN            NaN            NaN
#
#                  1963           1964     ...               2009          2010  \
# 0                 NaN            NaN     ...                NaN           NaN
# 1                 NaN            NaN     ...                NaN           NaN
# 2                 NaN            NaN     ...       1.884000e+01  2.068000e+01
# 3                 NaN            NaN     ...       4.485489e+01  4.270000e+01
# 4                 NaN            NaN     ...       3.184516e+01  3.240000e+01
# 5                 NaN            NaN     ...       8.535451e+01  8.280000e+01
# 6                 NaN            NaN     ...                NaN           NaN
# 347186           NaN           NaN          NaN
# 347187           NaN           NaN          NaN
# 347188           NaN           NaN          NaN
# 347189           NaN           NaN          NaN
# 347190           NaN           NaN          NaN
# 347191           NaN           NaN          NaN
# 347192           NaN           NaN          NaN
# 347193           NaN           NaN          NaN
# 347194           NaN           NaN          NaN
# 347195           NaN           NaN          NaN
# 347196           NaN           NaN          NaN
# 347197           NaN           NaN          NaN
# 347198           NaN           NaN          NaN
# 347199  5.900000e+01  5.910000e+01          NaN
#
# [347200 rows x 64 columns]

# %% [markdown]
# ## Indicator Codes and Indicator Name
#
# I selected the columns 'Indicator Name' and 'Indicator Code'.<br/>
# I deleted all duplicates, and then printed the top 5 and bottom 5 values. <br/>

# %%
wdi[['Indicator Name','Indicator Code']].drop_duplicates().head()
# Out:
#                                       Indicator Name     Indicator Code
# 0  2005 PPP conversion factor, GDP (LCU per inter...      PA.NUS.PPP.05
# 1  2005 PPP conversion factor, private consumptio...  PA.NUS.PRVT.PP.05
# 2  Access to clean fuels and technologies for coo...     EG.CFT.ACCS.ZS
# 3            Access to electricity (% of population)     EG.ELC.ACCS.ZS
# 4  Access to electricity, rural (% of rural popul...  EG.ELC.ACCS.RU.ZS

# %%
wdi[['Indicator Name','Indicator Code']].drop_duplicates().tail()
# Out:
#                                          Indicator Name     Indicator Code
# 1595  Women who believe a husband is justified in be...     SG.VAW.NEGL.ZS
# 1596  Women who believe a husband is justified in be...     SG.VAW.REFU.ZS
# 1597  Women who were first married by age 15 (% of w...  SP.M15.2024.FE.ZS
# 1598  Women who were first married by age 18 (% of w...  SP.M18.2024.FE.ZS
# 1599  Women's share of population ages 15+ living wi...  SH.DYN.AIDS.FE.ZS

# %%
# created a new dataframe made up of columns "Indicator name and indicator code"
# deleted duplicates
# set the column 'Indicator Code' as the index of indicators
indicators = ((wdi[['Indicator Name','Indicator Code']]).drop_duplicates()).set_index(['Indicator Code'])

# %% [markdown]
# Using 'indicators' DataFrame, i will be finding the 'Indicator Code' associated with the following observables:
# 1. 'Population',
# 2. 'GDP',
# 3. 'GINI index'

# %%
indicators[indicators['Indicator Name'].str.contains('Population, total')]
# Out:
#                    Indicator Name
# Indicator Code
# SP.POP.TOTL     Population, total

# %%
pd.set_option('display.max_rows', 500)
indicators[indicators['Indicator Name'].str.contains("GDP")]

# %%
indicators[indicators['Indicator Name'].str.contains('GINI index')]
# Out:
#                                   Indicator Name
# Indicator Code
# SI.POV.GINI     GINI index (World Bank estimate)

# %% [markdown]
# ## Extracting and Cleaning data from WDI and PWT
#
# From 'wdi' extract the columns 'Indicator Code', 'Country Code', and '2002'.
# Save the output in variable 'wdi_sample'

# %%
wdi_sample = wdi[['Indicator Code', 'Country Code', '2002']]

# %%
# selecting the lines associated with the indicator codes from wdi_sample
print(wdi_sample.loc[wdi_sample['Indicator Code'].isin(['SI.POV.GINI','SP.POP.TOTL','NY.GDP.MKTP.CD'])])
# Out:
#         Indicator Code Country Code          2002
# 525     NY.GDP.MKTP.CD          AFG  4.128821e+09
# 549        SI.POV.GINI          AFG           NaN
# 1147       SP.POP.TOTL          AFG  2.197992e+07
# 2125    NY.GDP.MKTP.CD          ALB  4.435079e+09
# 2149       SI.POV.GINI          ALB  3.170000e+01
# 2747       SP.POP.TOTL          ALB  3.051010e+06
# 3725    NY.GDP.MKTP.CD          DZA  5.676029e+10
# 3749       SI.POV.GINI          DZA           NaN
# 4347       SP.POP.TOTL          DZA  3.199505e+07
# 5325    NY.GDP.MKTP.CD          ASM  5.140000e+08
# 5349       SI.POV.GINI          ASM           NaN
# 5947       SP.POP.TOTL          ASM  5.873100e+04
# 6925    NY.GDP.MKTP.CD          AND  1.733117e+09
# 6949       SI.POV.GINI          AND           NaN
# 7547       SP.POP.TOTL          AND  7.004900e+04
# 8525    NY.GDP.MKTP.CD          AGO  1.249735e+10
# 8549       SI.POV.GINI          AGO           NaN
# 9147       SP.POP.TOTL          AGO  1.757265e+07
# 10125   NY.GDP.MKTP.CD          ATG  8.146153e+08
# 10149      SI.POV.GINI          ATG           NaN
# 10747      SP.POP.TOTL          ATG  8.626600e+04
# 11725   NY.GDP.MKTP.CD          ARG  9.772400e+10
# 11749      SI.POV.GINI          ARG  5.380000e+01
# 12347      SP.POP.TOTL          ARG  3.788937e+07
# 13325   NY.GDP.MKTP.CD          ARM  2.376335e+09
# 13349      SI.POV.GINI          ARM  3.480000e+01
# 13947      SP.POP.TOTL          ARM  3.033897e+06
# 14925   NY.GDP.MKTP.CD          ABW  1.941095e+09
# 14949      SI.POV.GINI          ABW           NaN
# 15547      SP.POP.TOTL          ABW  9.499200e+04
# ...                ...          ...           ...
# 331725  NY.GDP.MKTP.CD          URY  1.360649e+10
# 331749     SI.POV.GINI          URY           NaN
# 332347     SP.POP.TOTL          URY  3.327773e+06
# 333325  NY.GDP.MKTP.CD          UZB  9.687951e+09
# 333349     SI.POV.GINI          UZB  3.300000e+01
# 333947     SP.POP.TOTL          UZB  2.527185e+07
# 334925  NY.GDP.MKTP.CD          VUT  2.626038e+08
# 334949     SI.POV.GINI          VUT           NaN
# 335547     SP.POP.TOTL          VUT  1.939560e+05
# 336525  NY.GDP.MKTP.CD          VEN  9.289359e+10
# 336549     SI.POV.GINI          VEN  5.060000e+01
# 337147     SP.POP.TOTL          VEN  2.540870e+07
# 338125  NY.GDP.MKTP.CD          VNM  3.506411e+10
# 338149     SI.POV.GINI          VNM  3.700000e+01
# 338747     SP.POP.TOTL          VNM  8.195650e+07
# 339725  NY.GDP.MKTP.CD          VIR  3.269000e+09
# 339749     SI.POV.GINI          VIR           NaN
# 340347     SP.POP.TOTL          VIR  1.085100e+05
# 341325  NY.GDP.MKTP.CD          PSE  3.555800e+09
# 341349     SI.POV.GINI          PSE           NaN
# 341947     SP.POP.TOTL          PSE  3.075373e+06
# 342925  NY.GDP.MKTP.CD          YEM  1.069328e+10
# 342949     SI.POV.GINI          YEM           NaN
# 343547     SP.POP.TOTL          YEM  1.891918e+07
# 344525  NY.GDP.MKTP.CD          ZMB  4.193846e+09
# 344549     SI.POV.GINI          ZMB  4.210000e+01
# 345147     SP.POP.TOTL          ZMB  1.112041e+07
# 346125  NY.GDP.MKTP.CD          ZWE  6.342116e+09
# 346149     SI.POV.GINI          ZWE           NaN
# 346747     SP.POP.TOTL          ZWE  1.250052e+07
#
# [651 rows x 3 columns]

# %%
wdi_sample = wdi_sample.loc[wdi_sample['Indicator Code'].isin(['SI.POV.GINI','SP.POP.TOTL','NY.GDP.MKTP.CD'])]

# %%
# creating a pivot table in which values are the column '2002', the index is the 'Country Code', and the columns are the Indicator Codes.
wdi_sample = wdi_sample.pivot_table(values='2002',index='Country Code', columns='Indicator Code')

# %%
# renaming the column names of wdi_sample to 'Population', 'GDP', and 'GINI'
wdi_sample.columns = ['GDP', 'GINI', 'Population']

# %%
# selecting from "pwt" only values of the yaer 2002
# extracting "countrycode" and "hc"
# renaming 'countrycode' to 'Country Code'
pwt_sample =  pwt.loc[pwt['year'] == 2002][['countrycode','hc']].rename(columns={'countrycode': 'Country Code'})

# %%
# creating a new dataframe that contains the columns from wdi_sample and pwt_sample, matched by 'Country Code'
data = pd.concat([pwt_sample.set_index('Country Code'), wdi_sample], axis = 1)
# Out:
# /Users/adeoluwaakande/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:2: FutureWarning: Sorting because non-concatenation axis is not aligned. A future version
# of pandas will change to not sort by default.
#
# To accept the future behavior, pass 'sort=True'.
#
# To retain the current behavior and silence the warning, pass sort=False

# %% [markdown]
# Considering the data for the year 2002 that i have prepared above, i will
#  be performing the necessary data manipulations to answer the following questions:
#
# 1. Which countries have a population size of 10 million habitations +/- 1 million?
# 2. What is the average and the standard deviation in GDP of countries listed in 1?
# 3. What is the average and the standard deviation in the GDP of countries NOT listed in 1?
# 4. Repeat point 2 and 3 but for the GDP per capita.
# 5. What is the Country with the highest Human Capital (hc in the PWT tables)?
# 6. What is the Country with the Lowest Human Capital (hc in the PWT tables)?

# %%
data = data.reset_index()
data.rename(columns={'index':'Country'}, inplace=True)
Q1 = data.loc[(data['Population'] >= 9000000) & (data['Population'] <= 11000000), 'Country']
print(Q1)
# Out:
# 15     BEL
# 23     BLR
# 50     CZE
# 73     GIN
# 77     GRC
# 87     HUN
# 161    PRT
# 171    SEN
# 177    SOM
# 190    TCD
# 198    TUN
# Name: Country, dtype: object

# %%
mean_Q1 = (data.loc[data['Country'].isin(Q1)])["GDP"].mean()
std_Q1 = (data.loc[data['Country'].isin(Q1)])["GDP"].std()
print("The average is ",mean_Q1, "and the standard deviation is ", std_Q1)
# Out:
# The average is  74455540556.17746 and the standard deviation is  85204567133.23154

# %%
mean_Q3 = (data.loc[~data['Country'].isin(Q1)])["GDP"].mean()
std_Q3 = (data.loc[~data['Country'].isin(Q1)])["GDP"].std()
print("The average is ",mean_Q3, "and the standard deviation is ", std_Q3)
# Out:
# The average is  173731828490.20428 and the standard deviation is  880372555108.6028

# %%
mean_Q4_in = ((data.loc[data['Country'].isin(Q1)])["GDP"] / (data.loc[data['Country'].isin(Q1)])["Population"]).mean()
std_Q4_in = ((data.loc[data['Country'].isin(Q1)])["GDP"] / (data.loc[data['Country'].isin(Q1)])["Population"]).std()
mean_Q4_out = ((data.loc[~data['Country'].isin(Q1)])["GDP"] / (data.loc[~data['Country'].isin(Q1)])["Population"]).mean()
std_Q4_out = ((data.loc[~data['Country'].isin(Q1)])["GDP"] / (data.loc[~data['Country'].isin(Q1)])["Population"]).std()
print(mean_Q4_in,std_Q4_in, mean_Q4_out, std_Q4_out)
# Out:
# 7162.581644120961 8142.612572151089 8826.605448799437 14155.47950935825

# %%
print(data[['Country']][data.hc == data.hc.max()])
# Out:
#     Country
# 206     USA

# %%
print(data[['Country']][data.hc == data.hc.min()])
# Out:
#    Country
# 17     BFA
